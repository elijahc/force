# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout
init_notebook_mode(connected=True)
import numpy as np
from force import NeuronBath
from force import Simulation
from tqdm import tnrange, tqdm_notebook
from plotly.offline import iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
dt = 0.5
learn_every = 2
tt = 720 + 360
net = NeuronBath(N=1000,alpha=1)
sim = Simulation(net,nsecs=tt)
sim.run('training')
ts1 = sim.timeline 
#ts = np.arange(len(sim.timeline))
ft1 = Scatter(
    x=ts1,
    y=sim.ft,
    mode='lines',
    name='ft1')
trace2 = Scatter(
    x=ts1,
    y=sim.zt,
    mode='lines',
    name='zt1')
trace3 = Scatter(
    x=ts1,
    y=sim.wot,
    mode='lines',
    name='wot'
)
sim.run('testing',train=False,to=360)
ts2 = sim.timeline
ft2 = Scatter(
    x=ts2,
    y=sim.ft,
    mode='lines',
    name='ft2')
zt2 = Scatter(
    x=ts2,
    y=sim.zt,
    mode='lines',
    name='zt2')
wot2 = Scatter(
    x=ts2,
    y=sim.wot,
    mode='lines',
    name='wot2'
)
data = [ft1,trace2,ft2,zt2]


iplot(data)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6812b000018a> in <module>()
# ----> 1 iplot([{'x':ts1,'y':training_Pt}])
#
# NameError: name 'training_Pt' is not defined

# %%
N=500
net = NeuronBath(N=N,alpha=1.0)
sim = Simulation(network=net,nsecs=360)
sim.run('run',train=True)
ts1 = sim.timeline

z_tr = Scatter(
    x=ts1,
    y=sim.zt,
    mode='lines',
    name='zt')
wo_tr = Scatter(
    x=ts1,
    y=sim.wot,
    mode='lines',
    name='wot')
ft_tr = Scatter(x=ts1,y=sim.ft,mode='lines',name='ft')
iplot([z_tr,ft_tr,wo_tr])
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# ...

# %%
# Out:
# [ 0.          0.          0.01618119 ..., -0.01573764  0.00096853
#   0.01960095]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0a5e26e519a5> in <module>()
# ----> 1 rt = sim.rt[0,:]
#       2 rt = np.around(rt,decimals=5)
#       3 iplot([{'x':ts1,'y':rt}])
#       4
#
# AttributeError: 'Simulation' object has no attribute 'rt'
